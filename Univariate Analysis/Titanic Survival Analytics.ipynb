# %%
import pandas as pd

# %%
df = pd.read_csv("train (1).csv")

# %%
df["Survived"].unique()
# Out:
# array([0, 1], dtype=int64)

# %% [markdown]
# # Asking First Seven Question

# %% [markdown]
# Working On Categorical Column First

# %%
Categorical_Columns = ['Pclass','Survived','Sex', 'Age', 'SibSp','Parch', 'Ticket','Embarked']

# %%
df.shape
# Out:
# (891, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# Checking How many people are in Which class

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# Assuming df is your DataFrame
order = [3, 1, 2]  # Specify the order of Pclass values

sns.countplot(x="Pclass", data=df, order=order)

# Adding labels and title
plt.xlabel("Pclass")
plt.ylabel("Count")
plt.title("Distribution of Pclass")
plt.show()

# %% [markdown]
# # Mean Fare Price Checking

# %%
#Descriptive Basic Checking
df.groupby("Pclass")["Fare"].describe()
# Out:
#         count       mean        std  min       25%      50%   75%       max
# Pclass
# 1       216.0  84.154687  78.380373  0.0  30.92395  60.2875  93.5  512.3292
# 2       184.0  20.662183  13.417399  0.0  13.00000  14.2500  26.0   73.5000
# 3       491.0  13.675550  11.778142  0.0   7.75000   8.0500  15.5   69.5500

# %% [markdown]
# Create a box plot to visualize the distribution of fares for each passenger class. This can help you identify outliers, the central tendency, and the spread of fare prices within each class.

# %%
sns.boxplot(x = 'Pclass',y = 'Fare',data = df)
plt.title("Box Plot of fare prices by Class")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming df is your DataFrame with columns "Class" and "Fare"
sns.barplot(x='Pclass', y='Fare', data=df, estimator=max)
plt.title('Highest Fare Prices Class-wise')
plt.xlabel('Class')
plt.ylabel('Maximum Fare Price')
plt.show()

# %% [markdown]
# Checking The correlation Between the column seeing how they are dependent on class

# %%
correlation = df[["Pclass","Fare"]].corr()

# %%
#Correlation is telling between Pclass and Fare is when Class increases of a passenger means (1 class to 2nd class) then the Fare Decreases 
correlation
# Out:
#         Pclass    Fare
# Pclass  1.0000 -0.5495
# Fare   -0.5495  1.0000

# %% [markdown]
# Checking Gender Count

# %%
#Most are MALE
sns.countplot(x="Sex", data=df)
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %% [markdown]
# Checking Most of the people comes from what location

# %%
#So most of them are from South region
sns.countplot(x = 'Embarked',data = df)
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# AGE distribution

# %%
#checking for missing Values
missing_age = df["Age"].isnull().sum()
print(f"Missing values in Age: {missing_age}")
# Out:
# Missing values in Age: 177

# %%
df["Age"].min()
df["Age"].max()
# Out:
# 80.0

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df["Age"].dropna(),bins = 10,edgecolor = 'black')
plt.title("Distribution Of Age")
plt.xlabel("Age")
plt.ylabel("Frequency Count")
plt.show()

# %%
# Summary statistics
age_mean = df['Age'].mean()
age_median = df['Age'].median()
age_std = df['Age'].std()
print(f"Mean Age: {age_mean:.2f}, Median Age: {age_median:.2f}, Standard Deviation: {age_std:.2f}")
# Out:
# Mean Age: 29.70, Median Age: 28.00, Standard Deviation: 14.53

# %% [markdown]
# Checking For Siblings Count showing how many family members of a person is on board

# %%
# Plot count plot
sns.countplot(x = 'SibSp' ,data= df)
plt.title('Distribution of Siblings/Spouses Aboard')
plt.xlabel('SibSp')
plt.ylabel('Count')
plt.show()
#Concluding most of the people are without there family members

# %% [markdown]
# # Distribution Plot

# %%
#Checking the distribution of a plot of age that what probability if we pick random person that how much age of he is

# %%
sns.set(style="darkgrid")
sns.distplot(df['Age'])

#y-axis par probability hai or X-axis par age , bta ye raha k mene dekhna 20 age wale ki probability kia hai data me tu me 20 par jaonga waha se jaha line touch kar rhi hogi kde ki waha par jakar y axis se match karunga tu probability mill jai gi is case me 20 ki prob 27% hai
# Out:
# C:\Users\1285-010-001\AppData\Local\Temp\ipykernel_15324\4049448267.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
df["Age"].skew()
# Out:
# 0.38910778230082704
